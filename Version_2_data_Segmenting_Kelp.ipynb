# %% [markdown]
# <a href="https://colab.research.google.com/github/BRIJNANDA1979/Segmenting-Kelp-Forests-/blob/main/Version_2_data_Segmenting_Kelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cLEANED DATA 1323 IMAGES IN   tEST FOLDER  95 others are left out

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/KELP forest Satellite imagery Project Data/Test Features/df_test_ALL_labelled_cleaned.csv'

# %%
import pandas as pd

# %%
DF_CLEANED_test = pd.read_csv(path)

# %%
DF_CLEANED_test.describe()
# Out:
#         Unnamed: 0  Mean Reflectance      cvi Min      cvi Max         Green  \
# count  1323.000000       1323.000000  1323.000000  1323.000000   1323.000000
# mean    705.701436          0.039158     0.000030     1.740059   8474.429318
# std     417.799294          0.036444     0.000189    40.221459   1687.669317
# min       0.000000          0.004983     0.000000     0.038217    285.550694
# 25%     340.500000          0.024949     0.000000     0.140986   7973.157012
# 50%     689.000000          0.033202     0.000000     0.172114   8530.649127
# 75%    1076.500000          0.042959     0.000000     0.346990   9205.785971
# max    1425.000000          0.729695     0.004195  1395.382979  34080.612318
#
#                 NIR        Label
# count   1323.000000  1323.000000
# mean    8265.123659     0.999244
# std     1614.216479     0.027493
# min      169.858776     0.000000
# 25%     8059.995718     1.000000
# 50%     8446.554506     1.000000
# 75%     8842.620992     1.000000
# ...

# %%
DF_CLEANED_test.head()
# Out:
#    Unnamed: 0  Mean Reflectance   cvi Min   cvi Max        Green          NIR  \
# 0           0          0.026210  0.000000  0.131451  8505.616604  8527.619282
# 1           1          0.042957  0.000000  0.138197  9442.848400  8821.127747
# 2           2          0.028164  0.000000  0.168446  9332.627069  9355.326914
# 3           3          0.027128  0.000000  0.181175  9548.647355  9398.686098
# 4           4          0.035837  0.000089  0.195490  8774.165331  8733.073967
#
#                    images  Label
# 0  GD935309_satellite.tif      1
# 1  PP284888_satellite.tif      1
# 2  ZY575159_satellite.tif      1
# 3  SK539422_satellite.tif      1
# 4  XB663463_satellite.tif      1

# %%
Df_all = pd.read_csv('/content/drive/MyDrive/KELP forest Satellite imagery Project Data/Test Features/df_test_ALL_labelled.csv')

# %%
Df_all.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0  Mean Reflectance      cvi Min      cvi Max  \
# count   1426.000000  1426.000000       1426.000000  1426.000000  1426.000000
# mean     712.500000   712.500000          0.038289     0.000028     2.242487
# std      411.795054   411.795054          0.037913     0.000183    44.786098
# min        0.000000     0.000000          0.002644     0.000000     0.038217
# 25%      356.250000   356.250000          0.023909     0.000000     0.141708
# 50%      712.500000   712.500000          0.032256     0.000000     0.173276
# 75%     1068.750000  1068.750000          0.042335     0.000000     0.403819
# max     1425.000000  1425.000000          0.729695     0.004195  1395.382979
#
#               Green           NIR        Label
# count   1426.000000   1426.000000  1426.000000
# mean    7110.710142   6905.358156     0.994390
# std     5550.378430   5513.644904     0.074716
# min   -29933.076596 -30002.607796     0.000000
# ...

# %%
Df_all.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Mean Reflectance   cvi Min   cvi Max  \
# 0             0           0          0.026210  0.000000  0.131451
# 1             1           1          0.042957  0.000000  0.138197
# 2             2           2          0.028164  0.000000  0.168446
# 3             3           3          0.027128  0.000000  0.181175
# 4             4           4          0.035837  0.000089  0.195490
#
#          Green          NIR                  images  Label
# 0  8505.616604  8527.619282  GD935309_satellite.tif      1
# 1  9442.848400  8821.127747  PP284888_satellite.tif      1
# 2  9332.627069  9355.326914  ZY575159_satellite.tif      1
# 3  9548.647355  9398.686098  SK539422_satellite.tif      1
# 4  8774.165331  8733.073967  XB663463_satellite.tif      1

# %%
images_to_label_1 =DF_CLEANED_test['images'].tolist()

# %%
list_to_be_cleaned=[]
for row in Df_all.itertuples():
    if (row.images in images_to_label_1)==False:
        print(row.images)
        list_to_be_cleaned.append(row.images)
# Out:
# UF901834_satellite.tif
# CF841561_satellite.tif
# VO804900_satellite.tif
# OK930382_satellite.tif
# OU419443_satellite.tif
# XM276636_satellite.tif
# ZP147899_satellite.tif
# KP742064_satellite.tif
# SO225725_satellite.tif
# QX770879_satellite.tif
# KU205075_satellite.tif
# LV868260_satellite.tif
# CR918506_satellite.tif
# GF115017_satellite.tif
# DV681395_satellite.tif
# UD220878_satellite.tif
# OT906487_satellite.tif
# KZ797238_satellite.tif
# CA858232_satellite.tif
# FP798130_satellite.tif
# ME275113_satellite.tif
# AK488371_satellite.tif
# JU993559_satellite.tif
# YU468451_satellite.tif
# MP754960_satellite.tif
# HT224548_satellite.tif
# IK675571_satellite.tif
# AZ858214_satellite.tif
# HR677407_satellite.tif
# SO102818_satellite.tif
# MY658146_satellite.tif
# BD115626_satellite.tif
# MW364905_satellite.tif
# HS571366_satellite.tif
# RG275933_satellite.tif
# DA674348_satellite.tif
# DB103827_satellite.tif
# CR996302_satellite.tif
# IP903199_satellite.tif
# WJ866110_satellite.tif
# ...

# %%
list_to_be_cleaned[0:10]
# Out:
# ['UF901834_satellite.tif',
#  'CF841561_satellite.tif',
#  'VO804900_satellite.tif',
#  'OK930382_satellite.tif',
#  'OU419443_satellite.tif',
#  'XM276636_satellite.tif',
#  'ZP147899_satellite.tif',
#  'KP742064_satellite.tif',
#  'SO225725_satellite.tif',
#  'QX770879_satellite.tif']

# %%
len(list_to_be_cleaned)
# Out:
# 103

# %%
label = []
for row in Df_all.itertuples():
    if (row.images in list_to_be_cleaned)==True:
        label.append(0)
    else:
        label.append(1)

# %%
len(label)
# Out:
# 1426

# %%
Df_all['label'] = label

# %%
Df_all.drop('Label', inplace = True,axis=1)

# %%
Df_all.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Mean Reflectance   cvi Min   cvi Max  \
# 0             0           0          0.026210  0.000000  0.131451
# 1             1           1          0.042957  0.000000  0.138197
# 2             2           2          0.028164  0.000000  0.168446
# 3             3           3          0.027128  0.000000  0.181175
# 4             4           4          0.035837  0.000089  0.195490
#
#          Green          NIR                  images  label
# 0  8505.616604  8527.619282  GD935309_satellite.tif      1
# 1  9442.848400  8821.127747  PP284888_satellite.tif      1
# 2  9332.627069  9355.326914  ZY575159_satellite.tif      1
# 3  9548.647355  9398.686098  SK539422_satellite.tif      1
# 4  8774.165331  8733.073967  XB663463_satellite.tif      1

# %%
Df_all.drop('Unnamed: 0', inplace = True,axis=1)

# %%
Df_all.drop('Unnamed: 0.1', inplace = True,axis=1)

# %%
Df_all.head()
# Out:
#    Mean Reflectance   cvi Min   cvi Max        Green          NIR  \
# 0          0.026210  0.000000  0.131451  8505.616604  8527.619282
# 1          0.042957  0.000000  0.138197  9442.848400  8821.127747
# 2          0.028164  0.000000  0.168446  9332.627069  9355.326914
# 3          0.027128  0.000000  0.181175  9548.647355  9398.686098
# 4          0.035837  0.000089  0.195490  8774.165331  8733.073967
#
#                    images  label
# 0  GD935309_satellite.tif      1
# 1  PP284888_satellite.tif      1
# 2  ZY575159_satellite.tif      1
# 3  SK539422_satellite.tif      1
# 4  XB663463_satellite.tif      1

# %%
Df_all.describe()
# Out:
#        Mean Reflectance      cvi Min      cvi Max         Green           NIR  \
# count       1426.000000  1426.000000  1426.000000   1426.000000   1426.000000
# mean           0.038289     0.000028     2.242487   7110.710142   6905.358156
# std            0.037913     0.000183    44.786098   5550.378430   5513.644904
# min            0.002644     0.000000     0.038217 -29933.076596 -30002.607796
# 25%            0.023909     0.000000     0.141708   7835.210637   7912.217612
# 50%            0.032256     0.000000     0.173276   8460.166673   8387.210665
# 75%            0.042335     0.000000     0.403819   9146.572147   8815.494708
# max            0.729695     0.004195  1395.382979  34080.612318  36101.682963
#
#              label
# count  1426.000000
# mean      0.927770
# std       0.258959
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
Df_all.to_csv('/content/drive/MyDrive/KELP forest Satellite imagery Project Data/Test Features/All_Labelled_0_and_1.csv')

# %%
code_all = []
for row in Df_all.itertuples():
    if row.label==1:
        code_all.append('1'+str(row.images))
    else:
        code_all.append('0' + str(row.images))

# %%
code_all[1000:1010]
# Out:
# ['1VX671858_satellite.tif',
#  '1NB131244_satellite.tif',
#  '1GY452944_satellite.tif',
#  '1HQ731262_satellite.tif',
#  '1TI946335_satellite.tif',
#  '1RX356702_satellite.tif',
#  '0AV855731_satellite.tif',
#  '1EQ617488_satellite.tif',
#  '1ZJ351083_satellite.tif',
#  '0QT308573_satellite.tif']

# %%
pip install rasterio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 38.2 MB/s eta 0:00:00
# ...

# %%
import rasterio

# %%
path='/content/drive/MyDrive/KELP forest Satellite imagery Project Data/Test Features/test_features.tar_cVzb1K0/test_satellite'
submission_path = '/content/drive/MyDrive/KELP forest Satellite imagery Project Data/Submission'
for row in Df_all.itertuples():
    with rasterio.open(path+'/'+str(row.images))as src:
        data = src.read(1)
        # Register GDAL format drivers and configuration options with a
        # context manager.
        with rasterio.Env():

          # Write an array as a raster band to a new 8-bit file. For
          # the new file's profile, we start with the profile of the source
          profile = src.profile

          # And then change the band count to 1, set the
          # dtype to uint8, and specify LZW compression.
          profile.update(
                        dtype=rasterio.uint8,
                        count=1,
                        compress='lzw')
          if(row.label == 1):
            s = str(row.images)
            s= s.replace('satellite.tif','kelp.tif')
            with rasterio.open(submission_path + '/'+ s, 'w', **profile) as dst:
              dst.write(data.astype(rasterio.uint8), 1)
          # At the end of the ``with rasterio.Env()`` block, context
          # manager exits and all drivers are de-registered.
# Out:
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py:314: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(
